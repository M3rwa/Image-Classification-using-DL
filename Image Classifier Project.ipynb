# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn, optim
from torch import tensor
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.models as models
import argparse
from workspace_utils import keep_awake, active_session
from collections import OrderedDict
import json
import seaborn as sns
from PIL import Image
import time
import os

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_direction = 'flowers'
train_direction = data_direction + '/train'
valid_direction = data_direction + '/valid'
test_direction = data_direction + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets

train_data_transforms = transforms.Compose([
    transforms.Resize(255),
    transforms.CenterCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(30),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

val_data_transforms = transforms.Compose([
    transforms.Resize(255),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# TODO: Load the datasets with ImageFolder
train_photo = datasets.ImageFolder(train_direction, transform=train_data_transforms)
val_photo   = datasets.ImageFolder(valid_direction, transform=val_data_transforms)
test_photo = datasets.ImageFolder(test_direction, transform=val_data_transforms)

# TODO: Using the image datasets and the trainforms, define the dataloaders
train_loader = torch.utils.data.DataLoader(train_photo, 64, True)
val_loader   = torch.utils.data.DataLoader(val_photo,   32, True)
test_loader  = torch.utils.data.DataLoader(test_photo, 32, True)

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
len(cat_to_name)
# Out:
# 102

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
model = models.vgg19(pretrained=True)
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace)
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace)
#     (5): Dropout(p=0.5)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
clf = nn.Sequential(
    nn.Linear(25088, 512),
    nn.ReLU(),
    nn.Dropout(.5),
    nn.Linear(512, 102),
    nn.LogSoftmax(dim=1)
)

# %%
for param in model.parameters():
    param.requires_grad=False

# %%
model.classifier = clf

# %%
criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), 0.001 )

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
epochs = 3
iters = 0
train_loss=0
check_every = 1
model.to(device)
with active_session():
    for e in range(epochs):
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            iters += 0
            optimizer.zero_grad()
            out = model.forward(inputs)
            loss = criterion(out, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item()
            if iters%check_every == 0:
                model.eval()
                with torch.no_grad():
                    accuracy, loss_val = 0, 0
                    for imgs, classes in val_loader:
                        imgs, classes = imgs.to(device), classes.to(device)

                        pred = model.forward(imgs)
                        pred_loss = criterion(pred, classes)
                        loss_val += pred_loss.item()
                        
                        topv, topc = pred.topk(1, dim=1)
                        eq = topc == classes.view(*topc.shape)
                        accuracy += torch.mean(eq.type(torch.FloatTensor)).item()

                print(f"Epoch {e+1}/{epochs}.. "
                      f"Train loss: {train_loss/check_every:.3f}.. "
                      f"Test accuracy: {(accuracy/len(val_loader))*100:.2f}%"
                      f"Test loss: {loss_val/len(val_loader):.3f}.. ")
                
                train_loss = 0
                model.train()
# Out:
# Epoch 1/3.. Train loss: 4.634.. Test accuracy: 6.10%Test loss: 4.938..
# Epoch 1/3.. Train loss: 5.631.. Test accuracy: 8.53%Test loss: 4.929..
# Epoch 1/3.. Train loss: 5.316.. Test accuracy: 10.02%Test loss: 4.749..
# Epoch 1/3.. Train loss: 5.750.. Test accuracy: 13.98%Test loss: 4.449..
# Epoch 1/3.. Train loss: 5.331.. Test accuracy: 16.09%Test loss: 4.202..
# Epoch 1/3.. Train loss: 4.710.. Test accuracy: 12.15%Test loss: 4.128..
# Epoch 1/3.. Train loss: 4.948.. Test accuracy: 13.02%Test loss: 4.045..
# Epoch 1/3.. Train loss: 4.439.. Test accuracy: 14.61%Test loss: 3.917..
# Epoch 1/3.. Train loss: 4.327.. Test accuracy: 17.59%Test loss: 3.830..
# Epoch 1/3.. Train loss: 4.209.. Test accuracy: 17.59%Test loss: 3.767..
# Epoch 1/3.. Train loss: 4.165.. Test accuracy: 19.81%Test loss: 3.692..
# Epoch 1/3.. Train loss: 3.907.. Test accuracy: 22.01%Test loss: 3.634..
# Epoch 1/3.. Train loss: 3.743.. Test accuracy: 21.41%Test loss: 3.612..
# Epoch 1/3.. Train loss: 3.803.. Test accuracy: 20.54%Test loss: 3.594..
# Epoch 1/3.. Train loss: 3.982.. Test accuracy: 20.62%Test loss: 3.570..
# Epoch 1/3.. Train loss: 3.968.. Test accuracy: 22.37%Test loss: 3.523..
# Epoch 1/3.. Train loss: 3.772.. Test accuracy: 24.51%Test loss: 3.458..
# Epoch 1/3.. Train loss: 4.183.. Test accuracy: 27.40%Test loss: 3.390..
# Epoch 1/3.. Train loss: 4.041.. Test accuracy: 28.90%Test loss: 3.329..
# Epoch 1/3.. Train loss: 3.903.. Test accuracy: 30.45%Test loss: 3.273..
# Epoch 1/3.. Train loss: 3.417.. Test accuracy: 33.29%Test loss: 3.173..
# Epoch 1/3.. Train loss: 3.684.. Test accuracy: 34.66%Test loss: 3.123..
# Epoch 1/3.. Train loss: 3.780.. Test accuracy: 34.55%Test loss: 3.077..
# Epoch 1/3.. Train loss: 3.546.. Test accuracy: 35.16%Test loss: 3.001..
# Epoch 1/3.. Train loss: 3.664.. Test accuracy: 35.75%Test loss: 2.959..
# Epoch 1/3.. Train loss: 3.615.. Test accuracy: 34.94%Test loss: 2.930..
# Epoch 1/3.. Train loss: 3.217.. Test accuracy: 34.55%Test loss: 2.893..
# Epoch 1/3.. Train loss: 3.237.. Test accuracy: 34.46%Test loss: 2.861..
# Epoch 1/3.. Train loss: 3.289.. Test accuracy: 35.02%Test loss: 2.823..
# Epoch 1/3.. Train loss: 2.875.. Test accuracy: 37.02%Test loss: 2.742..
# Epoch 1/3.. Train loss: 3.202.. Test accuracy: 39.48%Test loss: 2.702..
# Epoch 1/3.. Train loss: 3.271.. Test accuracy: 40.77%Test loss: 2.675..
# Epoch 1/3.. Train loss: 3.395.. Test accuracy: 40.71%Test loss: 2.647..
# Epoch 1/3.. Train loss: 3.558.. Test accuracy: 41.52%Test loss: 2.618..
# Epoch 1/3.. Train loss: 2.798.. Test accuracy: 42.28%Test loss: 2.566..
# Epoch 1/3.. Train loss: 3.223.. Test accuracy: 42.15%Test loss: 2.548..
# Epoch 1/3.. Train loss: 2.965.. Test accuracy: 43.11%Test loss: 2.523..
# Epoch 1/3.. Train loss: 2.918.. Test accuracy: 43.30%Test loss: 2.496..
# Epoch 1/3.. Train loss: 2.800.. Test accuracy: 43.47%Test loss: 2.459..
# Epoch 1/3.. Train loss: 3.363.. Test accuracy: 43.92%Test loss: 2.435..
# Epoch 1/3.. Train loss: 2.955.. Test accuracy: 44.28%Test loss: 2.404..
# Epoch 1/3.. Train loss: 2.912.. Test accuracy: 45.82%Test loss: 2.387..
# Epoch 1/3.. Train loss: 3.031.. Test accuracy: 46.55%Test loss: 2.345..
# Epoch 1/3.. Train loss: 3.140.. Test accuracy: 48.13%Test loss: 2.350..
# Epoch 1/3.. Train loss: 3.052.. Test accuracy: 48.37%Test loss: 2.330..
# Epoch 1/3.. Train loss: 3.029.. Test accuracy: 49.52%Test loss: 2.299..
# Epoch 1/3.. Train loss: 2.916.. Test accuracy: 50.36%Test loss: 2.245..
# Epoch 1/3.. Train loss: 2.996.. Test accuracy: 50.79%Test loss: 2.205..
# Epoch 1/3.. Train loss: 2.657.. Test accuracy: 50.32%Test loss: 2.197..
# Epoch 1/3.. Train loss: 2.650.. Test accuracy: 49.43%Test loss: 2.177..
# Epoch 1/3.. Train loss: 2.349.. Test accuracy: 49.01%Test loss: 2.181..
# Epoch 1/3.. Train loss: 2.931.. Test accuracy: 47.93%Test loss: 2.187..
# Epoch 1/3.. Train loss: 2.867.. Test accuracy: 47.38%Test loss: 2.181..
# Epoch 1/3.. Train loss: 2.819.. Test accuracy: 47.29%Test loss: 2.154..
# Epoch 1/3.. Train loss: 2.651.. Test accuracy: 49.20%Test loss: 2.099..
# Epoch 1/3.. Train loss: 2.655.. Test accuracy: 50.33%Test loss: 2.058..
# Epoch 1/3.. Train loss: 2.443.. Test accuracy: 50.96%Test loss: 2.018..
# Epoch 1/3.. Train loss: 2.926.. Test accuracy: 52.35%Test loss: 1.986..
# Epoch 1/3.. Train loss: 2.415.. Test accuracy: 53.19%Test loss: 1.957..
# Epoch 1/3.. Train loss: 2.806.. Test accuracy: 54.46%Test loss: 1.934..
# Epoch 1/3.. Train loss: 2.598.. Test accuracy: 54.29%Test loss: 1.926..
# Epoch 1/3.. Train loss: 2.563.. Test accuracy: 53.94%Test loss: 1.920..
# Epoch 1/3.. Train loss: 2.506.. Test accuracy: 54.30%Test loss: 1.919..
# Epoch 1/3.. Train loss: 2.421.. Test accuracy: 54.30%Test loss: 1.927..
# Epoch 1/3.. Train loss: 2.681.. Test accuracy: 53.55%Test loss: 1.886..
# Epoch 1/3.. Train loss: 2.303.. Test accuracy: 53.45%Test loss: 1.887..
# Epoch 1/3.. Train loss: 2.390.. Test accuracy: 54.90%Test loss: 1.859..
# Epoch 1/3.. Train loss: 2.338.. Test accuracy: 54.85%Test loss: 1.836..
# Epoch 1/3.. Train loss: 2.260.. Test accuracy: 55.45%Test loss: 1.817..
# Epoch 1/3.. Train loss: 2.163.. Test accuracy: 56.34%Test loss: 1.785..
# Epoch 1/3.. Train loss: 2.034.. Test accuracy: 57.49%Test loss: 1.755..
# Epoch 1/3.. Train loss: 2.377.. Test accuracy: 58.21%Test loss: 1.728..
# Epoch 1/3.. Train loss: 1.858.. Test accuracy: 59.36%Test loss: 1.712..
# Epoch 1/3.. Train loss: 2.084.. Test accuracy: 59.08%Test loss: 1.707..
# Epoch 1/3.. Train loss: 2.292.. Test accuracy: 58.65%Test loss: 1.694..
# Epoch 1/3.. Train loss: 1.921.. Test accuracy: 59.33%Test loss: 1.663..
# Epoch 1/3.. Train loss: 2.049.. Test accuracy: 58.63%Test loss: 1.664..
# Epoch 1/3.. Train loss: 2.717.. Test accuracy: 58.93%Test loss: 1.653..
# Epoch 1/3.. Train loss: 2.351.. Test accuracy: 58.32%Test loss: 1.667..
# Epoch 1/3.. Train loss: 2.097.. Test accuracy: 58.32%Test loss: 1.654..
# Epoch 1/3.. Train loss: 1.887.. Test accuracy: 59.15%Test loss: 1.623..
# Epoch 1/3.. Train loss: 2.223.. Test accuracy: 60.23%Test loss: 1.596..
# Epoch 1/3.. Train loss: 2.130.. Test accuracy: 60.28%Test loss: 1.581..
# Epoch 1/3.. Train loss: 2.347.. Test accuracy: 60.72%Test loss: 1.566..
# Epoch 1/3.. Train loss: 2.102.. Test accuracy: 61.75%Test loss: 1.534..
# Epoch 1/3.. Train loss: 1.971.. Test accuracy: 63.96%Test loss: 1.494..
# Epoch 1/3.. Train loss: 2.151.. Test accuracy: 64.17%Test loss: 1.477..
# Epoch 1/3.. Train loss: 2.144.. Test accuracy: 65.97%Test loss: 1.468..
# Epoch 1/3.. Train loss: 2.302.. Test accuracy: 66.27%Test loss: 1.462..
# Epoch 1/3.. Train loss: 2.614.. Test accuracy: 66.75%Test loss: 1.451..
# Epoch 1/3.. Train loss: 1.611.. Test accuracy: 67.71%Test loss: 1.444..
# Epoch 1/3.. Train loss: 2.447.. Test accuracy: 66.80%Test loss: 1.434..
# Epoch 1/3.. Train loss: 2.103.. Test accuracy: 67.40%Test loss: 1.423..
# Epoch 1/3.. Train loss: 2.039.. Test accuracy: 66.80%Test loss: 1.409..
# Epoch 1/3.. Train loss: 1.971.. Test accuracy: 66.63%Test loss: 1.394..
# Epoch 1/3.. Train loss: 1.952.. Test accuracy: 67.37%Test loss: 1.395..
# Epoch 1/3.. Train loss: 1.793.. Test accuracy: 67.40%Test loss: 1.374..
# Epoch 1/3.. Train loss: 1.963.. Test accuracy: 68.92%Test loss: 1.349..
# Epoch 1/3.. Train loss: 1.756.. Test accuracy: 69.10%Test loss: 1.348..
# Epoch 1/3.. Train loss: 2.229.. Test accuracy: 68.19%Test loss: 1.346..
# Epoch 1/3.. Train loss: 1.867.. Test accuracy: 67.40%Test loss: 1.333..
# Epoch 1/3.. Train loss: 1.923.. Test accuracy: 67.61%Test loss: 1.322..
# Epoch 1/3.. Train loss: 2.055.. Test accuracy: 68.64%Test loss: 1.306..
# Epoch 2/3.. Train loss: 1.769.. Test accuracy: 67.13%Test loss: 1.300..
# Epoch 2/3.. Train loss: 1.669.. Test accuracy: 67.91%Test loss: 1.303..
# Epoch 2/3.. Train loss: 2.213.. Test accuracy: 69.22%Test loss: 1.274..
# Epoch 2/3.. Train loss: 1.795.. Test accuracy: 68.40%Test loss: 1.265..
# Epoch 2/3.. Train loss: 1.400.. Test accuracy: 69.27%Test loss: 1.258..
# Epoch 2/3.. Train loss: 1.481.. Test accuracy: 69.44%Test loss: 1.270..
# Epoch 2/3.. Train loss: 1.761.. Test accuracy: 70.03%Test loss: 1.250..
# Epoch 2/3.. Train loss: 1.457.. Test accuracy: 69.79%Test loss: 1.240..
# Epoch 2/3.. Train loss: 2.330.. Test accuracy: 69.23%Test loss: 1.252..
# Epoch 2/3.. Train loss: 1.625.. Test accuracy: 70.06%Test loss: 1.235..
# Epoch 2/3.. Train loss: 1.511.. Test accuracy: 69.12%Test loss: 1.241..
# Epoch 2/3.. Train loss: 1.511.. Test accuracy: 69.34%Test loss: 1.251..
# Epoch 2/3.. Train loss: 1.553.. Test accuracy: 68.44%Test loss: 1.288..
# Epoch 2/3.. Train loss: 1.783.. Test accuracy: 67.49%Test loss: 1.301..
# Epoch 2/3.. Train loss: 1.769.. Test accuracy: 67.61%Test loss: 1.310..
# Epoch 2/3.. Train loss: 2.167.. Test accuracy: 67.64%Test loss: 1.315..
# Epoch 2/3.. Train loss: 1.752.. Test accuracy: 68.58%Test loss: 1.312..
# Epoch 2/3.. Train loss: 1.560.. Test accuracy: 67.72%Test loss: 1.317..
# Epoch 2/3.. Train loss: 1.612.. Test accuracy: 68.96%Test loss: 1.291..
# Epoch 2/3.. Train loss: 2.145.. Test accuracy: 70.63%Test loss: 1.267..
# Epoch 2/3.. Train loss: 1.434.. Test accuracy: 70.99%Test loss: 1.247..
# Epoch 2/3.. Train loss: 1.623.. Test accuracy: 71.14%Test loss: 1.227..
# Epoch 2/3.. Train loss: 1.696.. Test accuracy: 71.14%Test loss: 1.209..
# Epoch 2/3.. Train loss: 1.491.. Test accuracy: 71.71%Test loss: 1.195..
# Epoch 2/3.. Train loss: 1.700.. Test accuracy: 71.62%Test loss: 1.189..
# Epoch 2/3.. Train loss: 1.327.. Test accuracy: 71.74%Test loss: 1.186..
# Epoch 2/3.. Train loss: 2.197.. Test accuracy: 71.17%Test loss: 1.192..
# Epoch 2/3.. Train loss: 1.637.. Test accuracy: 72.78%Test loss: 1.177..
# Epoch 2/3.. Train loss: 1.326.. Test accuracy: 72.56%Test loss: 1.158..
# Epoch 2/3.. Train loss: 1.625.. Test accuracy: 72.08%Test loss: 1.161..
# Epoch 2/3.. Train loss: 1.378.. Test accuracy: 70.99%Test loss: 1.168..
# Epoch 2/3.. Train loss: 1.626.. Test accuracy: 70.02%Test loss: 1.184..
# Epoch 2/3.. Train loss: 1.773.. Test accuracy: 70.42%Test loss: 1.171..
# Epoch 2/3.. Train loss: 1.643.. Test accuracy: 70.86%Test loss: 1.165..
# Epoch 2/3.. Train loss: 1.635.. Test accuracy: 70.55%Test loss: 1.169..
# Epoch 2/3.. Train loss: 1.490.. Test accuracy: 70.99%Test loss: 1.138..
# Epoch 2/3.. Train loss: 1.965.. Test accuracy: 71.61%Test loss: 1.129..
# Epoch 2/3.. Train loss: 1.803.. Test accuracy: 72.58%Test loss: 1.098..
# Epoch 2/3.. Train loss: 1.606.. Test accuracy: 73.40%Test loss: 1.072..
# Epoch 2/3.. Train loss: 1.600.. Test accuracy: 74.00%Test loss: 1.065..
# Epoch 2/3.. Train loss: 1.563.. Test accuracy: 74.09%Test loss: 1.047..
# Epoch 2/3.. Train loss: 1.938.. Test accuracy: 73.40%Test loss: 1.039..
# Epoch 2/3.. Train loss: 1.469.. Test accuracy: 73.60%Test loss: 1.043..
# Epoch 2/3.. Train loss: 1.390.. Test accuracy: 74.08%Test loss: 1.035..
# Epoch 2/3.. Train loss: 1.798.. Test accuracy: 75.56%Test loss: 1.018..
# Epoch 2/3.. Train loss: 1.409.. Test accuracy: 74.77%Test loss: 1.029..
# Epoch 2/3.. Train loss: 1.227.. Test accuracy: 73.22%Test loss: 1.045..
# Epoch 2/3.. Train loss: 1.815.. Test accuracy: 73.16%Test loss: 1.037..
# Epoch 2/3.. Train loss: 1.102.. Test accuracy: 71.96%Test loss: 1.038..
# Epoch 2/3.. Train loss: 1.574.. Test accuracy: 71.83%Test loss: 1.040..
# Epoch 2/3.. Train loss: 1.828.. Test accuracy: 72.52%Test loss: 1.054..
# Epoch 2/3.. Train loss: 1.671.. Test accuracy: 72.90%Test loss: 1.047..
# Epoch 2/3.. Train loss: 1.916.. Test accuracy: 72.61%Test loss: 1.041..
# Epoch 2/3.. Train loss: 1.434.. Test accuracy: 73.25%Test loss: 1.030..
# Epoch 2/3.. Train loss: 1.531.. Test accuracy: 74.81%Test loss: 1.027..
# Epoch 2/3.. Train loss: 1.420.. Test accuracy: 75.77%Test loss: 1.016..
# Epoch 2/3.. Train loss: 1.478.. Test accuracy: 75.59%Test loss: 1.014..
# Epoch 2/3.. Train loss: 1.543.. Test accuracy: 75.40%Test loss: 1.022..
# Epoch 2/3.. Train loss: 1.508.. Test accuracy: 75.87%Test loss: 0.997..
# Epoch 2/3.. Train loss: 1.268.. Test accuracy: 75.47%Test loss: 0.995..
# Epoch 2/3.. Train loss: 1.185.. Test accuracy: 75.04%Test loss: 0.990..
# Epoch 2/3.. Train loss: 1.333.. Test accuracy: 76.04%Test loss: 0.965..
# Epoch 2/3.. Train loss: 1.603.. Test accuracy: 74.92%Test loss: 0.965..
# Epoch 2/3.. Train loss: 1.596.. Test accuracy: 75.52%Test loss: 0.958..
# Epoch 2/3.. Train loss: 1.668.. Test accuracy: 75.52%Test loss: 0.952..
# Epoch 2/3.. Train loss: 1.419.. Test accuracy: 75.65%Test loss: 0.939..
# Epoch 2/3.. Train loss: 1.572.. Test accuracy: 75.00%Test loss: 0.944..
# Epoch 2/3.. Train loss: 1.767.. Test accuracy: 75.01%Test loss: 0.946..
# Epoch 2/3.. Train loss: 1.460.. Test accuracy: 75.23%Test loss: 0.945..
# Epoch 2/3.. Train loss: 1.238.. Test accuracy: 75.43%Test loss: 0.949..
# Epoch 2/3.. Train loss: 1.418.. Test accuracy: 75.79%Test loss: 0.942..
# Epoch 2/3.. Train loss: 1.448.. Test accuracy: 76.76%Test loss: 0.926..
# Epoch 2/3.. Train loss: 1.212.. Test accuracy: 77.27%Test loss: 0.905..
# Epoch 2/3.. Train loss: 1.483.. Test accuracy: 77.30%Test loss: 0.897..
# Epoch 2/3.. Train loss: 1.331.. Test accuracy: 77.22%Test loss: 0.887..
# Epoch 2/3.. Train loss: 1.456.. Test accuracy: 77.10%Test loss: 0.889..
# Epoch 2/3.. Train loss: 1.734.. Test accuracy: 77.08%Test loss: 0.907..
# Epoch 2/3.. Train loss: 1.733.. Test accuracy: 77.10%Test loss: 0.909..
# Epoch 2/3.. Train loss: 1.362.. Test accuracy: 76.86%Test loss: 0.924..
# Epoch 2/3.. Train loss: 1.333.. Test accuracy: 76.40%Test loss: 0.934..
# Epoch 2/3.. Train loss: 1.377.. Test accuracy: 76.16%Test loss: 0.941..
# Epoch 2/3.. Train loss: 1.293.. Test accuracy: 75.37%Test loss: 0.947..
# Epoch 2/3.. Train loss: 1.374.. Test accuracy: 75.35%Test loss: 0.947..
# Epoch 2/3.. Train loss: 1.584.. Test accuracy: 75.61%Test loss: 0.960..
# Epoch 2/3.. Train loss: 1.331.. Test accuracy: 75.07%Test loss: 0.975..
# Epoch 2/3.. Train loss: 1.752.. Test accuracy: 75.85%Test loss: 0.958..
# Epoch 2/3.. Train loss: 1.735.. Test accuracy: 75.28%Test loss: 0.963..
# Epoch 2/3.. Train loss: 1.365.. Test accuracy: 76.10%Test loss: 0.955..
# Epoch 2/3.. Train loss: 1.331.. Test accuracy: 76.46%Test loss: 0.950..
# Epoch 2/3.. Train loss: 1.274.. Test accuracy: 75.95%Test loss: 0.946..
# Epoch 2/3.. Train loss: 1.485.. Test accuracy: 76.31%Test loss: 0.949..
# Epoch 2/3.. Train loss: 1.103.. Test accuracy: 75.23%Test loss: 0.956..
# Epoch 2/3.. Train loss: 1.241.. Test accuracy: 75.37%Test loss: 0.946..
# Epoch 2/3.. Train loss: 1.311.. Test accuracy: 73.84%Test loss: 0.946..
# Epoch 2/3.. Train loss: 2.011.. Test accuracy: 74.80%Test loss: 0.938..
# Epoch 2/3.. Train loss: 1.548.. Test accuracy: 74.77%Test loss: 0.931..
# Epoch 2/3.. Train loss: 1.538.. Test accuracy: 74.63%Test loss: 0.921..
# Epoch 2/3.. Train loss: 1.132.. Test accuracy: 74.00%Test loss: 0.916..
# Epoch 2/3.. Train loss: 1.535.. Test accuracy: 74.87%Test loss: 0.913..
# Epoch 2/3.. Train loss: 1.108.. Test accuracy: 74.41%Test loss: 0.907..
# Epoch 2/3.. Train loss: 1.479.. Test accuracy: 74.65%Test loss: 0.901..
# Epoch 2/3.. Train loss: 1.391.. Test accuracy: 75.04%Test loss: 0.905..
# Epoch 2/3.. Train loss: 1.432.. Test accuracy: 75.76%Test loss: 0.902..
# Epoch 3/3.. Train loss: 1.142.. Test accuracy: 75.83%Test loss: 0.889..
# Epoch 3/3.. Train loss: 1.244.. Test accuracy: 77.00%Test loss: 0.880..
# Epoch 3/3.. Train loss: 1.449.. Test accuracy: 76.76%Test loss: 0.877..
# Epoch 3/3.. Train loss: 1.600.. Test accuracy: 77.19%Test loss: 0.858..
# Epoch 3/3.. Train loss: 1.589.. Test accuracy: 76.84%Test loss: 0.861..
# Epoch 3/3.. Train loss: 1.228.. Test accuracy: 77.20%Test loss: 0.858..
# Epoch 3/3.. Train loss: 1.355.. Test accuracy: 77.80%Test loss: 0.844..
# Epoch 3/3.. Train loss: 1.400.. Test accuracy: 78.23%Test loss: 0.834..
# Epoch 3/3.. Train loss: 1.371.. Test accuracy: 77.42%Test loss: 0.844..
# Epoch 3/3.. Train loss: 1.319.. Test accuracy: 77.82%Test loss: 0.836..
# Epoch 3/3.. Train loss: 1.160.. Test accuracy: 77.44%Test loss: 0.854..
# Epoch 3/3.. Train loss: 1.233.. Test accuracy: 77.46%Test loss: 0.853..
# Epoch 3/3.. Train loss: 1.745.. Test accuracy: 75.97%Test loss: 0.859..
# Epoch 3/3.. Train loss: 1.294.. Test accuracy: 75.61%Test loss: 0.865..
# Epoch 3/3.. Train loss: 1.563.. Test accuracy: 75.73%Test loss: 0.867..
# Epoch 3/3.. Train loss: 1.289.. Test accuracy: 75.28%Test loss: 0.859..
# Epoch 3/3.. Train loss: 1.461.. Test accuracy: 75.45%Test loss: 0.864..
# Epoch 3/3.. Train loss: 1.120.. Test accuracy: 75.73%Test loss: 0.854..
# Epoch 3/3.. Train loss: 1.111.. Test accuracy: 76.98%Test loss: 0.841..
# Epoch 3/3.. Train loss: 1.132.. Test accuracy: 77.32%Test loss: 0.843..
# Epoch 3/3.. Train loss: 1.138.. Test accuracy: 78.15%Test loss: 0.833..
# Epoch 3/3.. Train loss: 1.223.. Test accuracy: 78.57%Test loss: 0.827..
# Epoch 3/3.. Train loss: 1.316.. Test accuracy: 78.02%Test loss: 0.819..
# Epoch 3/3.. Train loss: 0.943.. Test accuracy: 77.80%Test loss: 0.815..
# Epoch 3/3.. Train loss: 1.264.. Test accuracy: 78.07%Test loss: 0.810..
# Epoch 3/3.. Train loss: 1.173.. Test accuracy: 78.71%Test loss: 0.799..
# Epoch 3/3.. Train loss: 1.032.. Test accuracy: 78.11%Test loss: 0.797..
# Epoch 3/3.. Train loss: 0.944.. Test accuracy: 78.42%Test loss: 0.798..
# Epoch 3/3.. Train loss: 1.237.. Test accuracy: 78.33%Test loss: 0.809..
# Epoch 3/3.. Train loss: 0.993.. Test accuracy: 78.11%Test loss: 0.815..
# Epoch 3/3.. Train loss: 0.858.. Test accuracy: 77.87%Test loss: 0.809..
# Epoch 3/3.. Train loss: 1.138.. Test accuracy: 77.15%Test loss: 0.811..
# Epoch 3/3.. Train loss: 1.004.. Test accuracy: 77.68%Test loss: 0.813..
# Epoch 3/3.. Train loss: 1.253.. Test accuracy: 77.63%Test loss: 0.808..
# Epoch 3/3.. Train loss: 1.204.. Test accuracy: 77.15%Test loss: 0.800..
# Epoch 3/3.. Train loss: 0.983.. Test accuracy: 77.42%Test loss: 0.799..
# Epoch 3/3.. Train loss: 1.047.. Test accuracy: 77.68%Test loss: 0.790..
# Epoch 3/3.. Train loss: 0.761.. Test accuracy: 78.69%Test loss: 0.771..
# Epoch 3/3.. Train loss: 1.184.. Test accuracy: 79.71%Test loss: 0.752..
# Epoch 3/3.. Train loss: 1.048.. Test accuracy: 79.43%Test loss: 0.742..
# Epoch 3/3.. Train loss: 0.879.. Test accuracy: 80.10%Test loss: 0.727..
# Epoch 3/3.. Train loss: 0.975.. Test accuracy: 81.00%Test loss: 0.730..
# Epoch 3/3.. Train loss: 1.179.. Test accuracy: 79.94%Test loss: 0.734..
# Epoch 3/3.. Train loss: 1.317.. Test accuracy: 80.01%Test loss: 0.739..
# Epoch 3/3.. Train loss: 1.037.. Test accuracy: 79.77%Test loss: 0.740..
# Epoch 3/3.. Train loss: 1.072.. Test accuracy: 79.86%Test loss: 0.742..
# Epoch 3/3.. Train loss: 1.520.. Test accuracy: 79.61%Test loss: 0.754..
# Epoch 3/3.. Train loss: 0.702.. Test accuracy: 79.77%Test loss: 0.743..
# Epoch 3/3.. Train loss: 0.817.. Test accuracy: 79.22%Test loss: 0.746..
# Epoch 3/3.. Train loss: 1.288.. Test accuracy: 79.01%Test loss: 0.744..
# Epoch 3/3.. Train loss: 1.002.. Test accuracy: 79.82%Test loss: 0.731..
# Epoch 3/3.. Train loss: 1.183.. Test accuracy: 80.48%Test loss: 0.735..
# Epoch 3/3.. Train loss: 1.028.. Test accuracy: 81.21%Test loss: 0.722..
# Epoch 3/3.. Train loss: 0.958.. Test accuracy: 80.82%Test loss: 0.730..
# Epoch 3/3.. Train loss: 0.852.. Test accuracy: 80.73%Test loss: 0.733..
# Epoch 3/3.. Train loss: 1.502.. Test accuracy: 80.94%Test loss: 0.735..
# Epoch 3/3.. Train loss: 1.156.. Test accuracy: 80.25%Test loss: 0.754..
# Epoch 3/3.. Train loss: 1.031.. Test accuracy: 80.28%Test loss: 0.755..
# Epoch 3/3.. Train loss: 0.931.. Test accuracy: 80.18%Test loss: 0.775..
# Epoch 3/3.. Train loss: 0.984.. Test accuracy: 79.49%Test loss: 0.772..
# Epoch 3/3.. Train loss: 1.189.. Test accuracy: 80.06%Test loss: 0.788..
# Epoch 3/3.. Train loss: 1.158.. Test accuracy: 79.91%Test loss: 0.793..
# Epoch 3/3.. Train loss: 1.097.. Test accuracy: 79.67%Test loss: 0.792..
# Epoch 3/3.. Train loss: 0.978.. Test accuracy: 80.15%Test loss: 0.781..
# Epoch 3/3.. Train loss: 1.622.. Test accuracy: 80.52%Test loss: 0.777..
# Epoch 3/3.. Train loss: 1.360.. Test accuracy: 81.33%Test loss: 0.777..
# Epoch 3/3.. Train loss: 0.975.. Test accuracy: 80.86%Test loss: 0.793..
# Epoch 3/3.. Train loss: 0.954.. Test accuracy: 80.61%Test loss: 0.771..
# Epoch 3/3.. Train loss: 1.098.. Test accuracy: 80.70%Test loss: 0.762..
# Epoch 3/3.. Train loss: 1.219.. Test accuracy: 80.94%Test loss: 0.768..
# Epoch 3/3.. Train loss: 1.173.. Test accuracy: 80.32%Test loss: 0.767..
# Epoch 3/3.. Train loss: 1.475.. Test accuracy: 79.94%Test loss: 0.771..
# Epoch 3/3.. Train loss: 1.766.. Test accuracy: 79.85%Test loss: 0.766..
# Epoch 3/3.. Train loss: 1.157.. Test accuracy: 79.79%Test loss: 0.758..
# Epoch 3/3.. Train loss: 1.139.. Test accuracy: 80.49%Test loss: 0.748..
# Epoch 3/3.. Train loss: 1.339.. Test accuracy: 80.94%Test loss: 0.737..
# Epoch 3/3.. Train loss: 1.157.. Test accuracy: 80.84%Test loss: 0.734..
# Epoch 3/3.. Train loss: 0.828.. Test accuracy: 81.12%Test loss: 0.726..
# Epoch 3/3.. Train loss: 0.948.. Test accuracy: 81.57%Test loss: 0.722..
# Epoch 3/3.. Train loss: 1.537.. Test accuracy: 81.54%Test loss: 0.726..
# Epoch 3/3.. Train loss: 1.097.. Test accuracy: 81.04%Test loss: 0.732..
# Epoch 3/3.. Train loss: 1.003.. Test accuracy: 80.34%Test loss: 0.746..
# Epoch 3/3.. Train loss: 1.010.. Test accuracy: 80.73%Test loss: 0.747..
# Epoch 3/3.. Train loss: 1.233.. Test accuracy: 80.64%Test loss: 0.757..
# Epoch 3/3.. Train loss: 1.199.. Test accuracy: 80.40%Test loss: 0.755..
# Epoch 3/3.. Train loss: 1.438.. Test accuracy: 80.07%Test loss: 0.756..
# Epoch 3/3.. Train loss: 1.102.. Test accuracy: 80.18%Test loss: 0.766..
# Epoch 3/3.. Train loss: 1.333.. Test accuracy: 79.85%Test loss: 0.776..
# Epoch 3/3.. Train loss: 0.847.. Test accuracy: 80.19%Test loss: 0.767..
# Epoch 3/3.. Train loss: 0.938.. Test accuracy: 80.01%Test loss: 0.770..
# Epoch 3/3.. Train loss: 1.128.. Test accuracy: 79.91%Test loss: 0.768..
# Epoch 3/3.. Train loss: 1.474.. Test accuracy: 80.15%Test loss: 0.760..
# Epoch 3/3.. Train loss: 1.609.. Test accuracy: 81.09%Test loss: 0.742..
# Epoch 3/3.. Train loss: 1.013.. Test accuracy: 80.52%Test loss: 0.740..
# Epoch 3/3.. Train loss: 1.135.. Test accuracy: 81.00%Test loss: 0.738..
# Epoch 3/3.. Train loss: 0.884.. Test accuracy: 80.58%Test loss: 0.741..
# Epoch 3/3.. Train loss: 1.270.. Test accuracy: 80.88%Test loss: 0.731..
# Epoch 3/3.. Train loss: 1.283.. Test accuracy: 82.12%Test loss: 0.715..
# Epoch 3/3.. Train loss: 1.912.. Test accuracy: 81.78%Test loss: 0.718..
# Epoch 3/3.. Train loss: 1.399.. Test accuracy: 81.36%Test loss: 0.714..
# Epoch 3/3.. Train loss: 1.239.. Test accuracy: 81.90%Test loss: 0.711..
# Epoch 3/3.. Train loss: 1.216.. Test accuracy: 81.18%Test loss: 0.703..
# Epoch 3/3.. Train loss: 1.052.. Test accuracy: 80.46%Test loss: 0.706..

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
test_loss = 0
acc = 0

for imgs, labels in test_loader:
    model.eval()
    imgs, labels = imgs.to(device), labels.to(device)
    with torch.no_grad():
        
        out = model.forward(imgs)
        loss = criterion(out, labels)
        test_loss += loss.item()
        
        pred = torch.exp(out)
        max_v, max_k = pred.topk(1, dim=1)
        eq = max_k == labels.view(*max_k.shape)
        
        acc += torch.mean(eq.type(torch.FloatTensor)).item()
        
print(f'Test Loss: {test_loss/len(test_loader):.4f}\nTest Accuracy: {(acc/len(test_loader))*100:.2f}%')
# Out:
# Test Loss: 0.8649
# Test Accuracy: 76.75%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
model.to('cpu')
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=512, out_features=102, bias=True)
#     (4): LogSoftmax()
#   )
# )

# %%
# TODO: Save the checkpoint 
model.class2idx = train_photo.class_to_idx
checkpoint = {
      'model':'vgg16',
      'input_size': 25088,
      'output_size': 102,
      'batch_size': 64,
      'epochs' : 4,
      'optimizer': optimizer.state_dict(),
      'classifier': model.classifier,
      'class2idx': model.class2idx,
      'state_dict': model.state_dict()
}

torch.save(checkpoint, 'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
def load(path):
    checkpoint = torch.load(path, map_location='cpu')
    model_name = checkpoint['model']
    model = getattr(models, checkpoint['model'])(pretrained=True)
    model.state_dict = model.state_dict()
    model.classifier = checkpoint['classifier']
    model.class2idx = checkpoint['class2idx']
    model.epochs = checkpoint['epochs']
    optimizer = optim.Adam(model.classifier.parameters())
    optimizer.load_state_dict(checkpoint['optimizer'])
    
    return model, optimizer

# %%
model, optimizer = load('checkpoint.pth')
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.5)
#     (3): Linear(in_features=512, out_features=102, bias=True)
#     (4): LogSoftmax()
#   )
# )

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
# TODO: Process a PIL image for use in a PyTorch model
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''
    # TODO: Process a PIL image for use in a PyTorch model
    img = Image.open(image)
    img = img.resize((256, 256))
    v = 0.5*(256-224)
    img = img.crop((v, v, 256-v, 256-v))
    
    img = np.array(img)/255
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    img = (img - mean) / std

    return img.transpose(2,0,1)

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    ax.imshow(image)
    
    return ax

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    # TODO: Implement the code to predict the class from an image file
    img = process_image(image_path)
    img = torch.from_numpy(np.array([img])).float()
    
    model.eval()
    out = model.forward(img)
    out = torch.exp(out)
    
    top_v, top_k = out.topk(topk, dim=1)
    props = top_v
    classes = [model.class2idx[str(k)] for k in top_k[0].numpy()]
    return props, classes

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes

# %%
import torch
from torch import nn, optim
from torchvision import transforms, datasets, models

from workspace_utils import keep_awake, active_session

from PIL import Image
import matplotlib.pyplot as plt

import numpy as np

import os

# %%
def sanity_check(topk=5):
    sample = np.random.choice(os.listdir('./flowers/test/7/'))
    img_path = './flowers/test/7/' + sample

    props, idx = predict(img_path, model, topk)
    props = props[0].detach().numpy()
    
    labels = [cat_to_name[str(n+1)] for n in idx]
    cls_name = labels[np.argmax(props)]
    
    imshow(process_image(img_path))
    plt.axis('off')
    plt.title(cls_name)
    
    plt.figure(figsize=(7, 3))
    plt.barh(labels, props)
    
    plt.show()

# %%
sanity_check(5)

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
